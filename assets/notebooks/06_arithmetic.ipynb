# %% [markdown]
# ## Before You Begin
#
# Recommended steps:
# - Save your own copy of this notebook: File → Save a copy in Drive.
# - Run all cells from top to bottom.
# - Edit code only where the instructions indicate.
# - This notebook uses basic Python only; it does not connect to external files or services.
# - If something stops working, restart the notebook: Runtime → Restart session.

# %% [markdown]
# # Arithmetic Operations
#
# In this notebook, you will practice basic arithmetic operations in Python, including addition, subtraction, multiplication, division, modulus, and integer division.
#
# You will complete **ten exercises** to reinforce these concepts.

# %% [markdown]
# ## 1. Warm-Up Exercise (1 of 10)
# ### 1.1 Simple addition
# Add two numbers and print the result.

# %%
a = 7
b = 5
result = ___  # Replace with: a + b
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# a = 7
# b = 5
# result = a + b
# print(result)
# ```
# </details>

# %% [markdown]
# ## 2. Core Concepts (Exercises 2–5 of 10)
# Practice essential arithmetic operations.

# %% [markdown]
# ### 2.1 Subtraction
# Compute 20 minus 5 and print it.

# %%
result = ___  # Replace with: 20 - 5
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# result = 20 - 5
# print(result)
# ```
# </details>

# %% [markdown]
# ### 2.2 Multiplication
# Multiply 4 by 6 and print the result.

# %%
result = ___  # Replace with: 4 * 6
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# result = 4 * 6
# print(result)
# ```
# </details>

# %% [markdown]
# ### 2.3 Division
# Divide 15 by 4 and print the result.

# %%
result = ___  # Replace with: 15 / 4
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# result = 15 / 4
# print(result)
# ```
# </details>

# %% [markdown]
# ### 2.4 Integer division and modulus
# Compute 17 // 3 and 17 % 3, store them in `int_div` and `remainder`.

# %%
int_div = ___  # Replace with: 17 // 3
remainder = ___  # Replace with: 17 % 3
print(int_div, remainder)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# int_div = 17 // 3
# remainder = 17 % 3
# print(int_div, remainder)
# ```
# </details>

# %% [markdown]
# ## 3. Guided Practice (Exercises 6–8 of 10)
# Work carefully and modify only the indicated lines.

# %% [markdown]
# ### 3.1 Calculate total cost
# A store gives a 16% tax. Update the value of `cost` so it reflects the total price including tax.

# %%
cost = 200
total_cost = ___  # Replace with: cost * 1.16
print(total_cost)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# cost = 200
# total_cost = cost * 1.16
# print(total_cost)
# ```
# </details>

# %% [markdown]
# ### 3.2 Compute average
# Calculate the average of three numbers: 10, 20, 30.

# %%
num1 = 10
num2 = 20
num3 = 30
average = ___  # Replace with: (num1 + num2 + num3) / 3
print(average)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# num1 = 10
# num2 = 20
# num3 = 30
# average = (num1 + num2 + num3) / 3
# print(average)
# ```
# </details>

# %% [markdown]
# ### 3.3 Update a variable
# Increase `points` by 50.

# %%
points = 120
points = ___  # Replace with: points + 50
print(points)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# points = 120
# points = points + 50
# print(points)
# ```
# </details>

# %% [markdown]
# ## 4. Mini-Challenge (Exercises 9–10 of 10)
# These exercises integrate multiple arithmetic operations. Complete them fully and check your results manually.

# %% [markdown]
# ### 4.1 Shopping discount calculator
# Ask for the price and the discount percent, compute the final price after discount, and print it.
# Use the space below to write your code.

# %%
# Write your code here
# 1. Ask the user for the price and save it as a float
# 2. Ask the user for the discount percent and save it as a float
# 3. Compute the final price after discount: final_price = price * (1 - discount_percent / 100)
# 4. Print the final price

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# price = float(input('Enter price: '))
# discount_percent = float(input('Enter discount percent: '))
# final_price = price * (1 - discount_percent / 100)
# print(final_price)
# ```
# </details>

# %% [markdown]
# ### 4.2 Body mass index (BMI) calculator
# Ask the user for weight in kilograms and height in meters, compute BMI = weight / (height ** 2), and print it.
# Use the space below to write your code.

# %%
# Write your code here
# 1. Ask the user for weight in kg and save as float
# 2. Ask the user for height in meters and save as float
# 3. Compute BMI: BMI = weight / (height squared)
# 4. Print the BMI

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# weight = float(input('Enter weight in kg: '))
# height = float(input('Enter height in meters: '))
# bmi = weight / (height ** 2)
# print(bmi)
# ```
# </details>

# %% [markdown]
# ---
# ## You're done!
# You practiced:
# - Addition, subtraction, multiplication, division, integer division, and modulus
# - Updating variables
# - Applying arithmetic operations in small programs
#
# Great work! Continue with the next notebook when ready.
