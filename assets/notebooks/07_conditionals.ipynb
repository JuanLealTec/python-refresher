# %% [markdown]
# ## Before You Begin
#
# Recommended steps:
# - Save your own copy of this notebook: **File → Save a copy in Drive**.
# - Run all cells **from top to bottom**.
# - Edit code **only where the instructions indicate**.
# - This notebook uses basic Python only; it does not connect to external files or services.
# - If something stops working: **Runtime → Restart session**.

# %% [markdown]
# # Conditionals & Relational Operators
#
# In this notebook, you will practice Python conditional statements (`if` and `else`) and the use of relational operators.
#
# You will complete ten exercises to reinforce these concepts.

# %% [markdown]
# ## 1. Warm-Up Exercise (1 of 10)

# %% [markdown]
# ### 1.1. Compare Two Numbers (Exercise 1)
# Check if 5 is greater than 3 and print the boolean result.

# %%
result = ___  # <-- Replace with: 5 > 3
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# result = 5 > 3
# print(result)
# ```
# </details>

# %% [markdown]
# ## 2. Core Concepts (Exercises 2-5 of 10)

# %% [markdown]
# ### 2.1. Simple `if` Statement (Exercise 2)
# Print "Yes" if a number is positive.

# %%
number = 7
if ___:  # Replace with: number > 0
    print("Yes")

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 7
# if number > 0:
#     print("Yes")
# ```
# </details>

# %% [markdown]
# ### 2.2. `If-Else` Statement (Exercise 3)
# Print "Even" if a number is even, otherwise print "Odd".

# %%
number = 8
if number % 2 == 0:
    print("Even")
else:
    print(___)  # Replace with: "Odd"

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 8
# if number % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
# ```
# </details>

# %% [markdown]
# ### 2.3. Using the Not Equal Operator (`!=`) (Exercise 4)
# Define `user_role = "guest"`. Use an `if` statement to print "Access Denied" only if `user_role` is not equal to `"admin"`.

# %%
user_role = "guest"
if ___:  # Replace with: user_role != "admin"
    print("Access Denied")

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# user_role = "guest"
# if user_role != "admin":
#     print("Access Denied")
# ```
# </details>

# %% [markdown]
# ### 2.4. Nested `if` Statements (Exercise 5)
# Check if a number is positive and even, and print a message.

# %%
number = 4
if number > 0:
    if ___:  # Replace with: number % 2 == 0
        print("Positive and even")
    else:
        print("Positive but odd")

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 4
# if number > 0:
#     if number % 2 == 0:
#         print("Positive and even")
#     else:
#         print("Positive but odd")
# ```
# </details>

# %% [markdown]
# ## 3. Guided Practice (Exercises 6-8 of 10)

# %% [markdown]
# ### 3.1. Age Check (Exercise 6)
# Ask the user for their age. Use a conditional expression to set `status` as "Adult" if 18 or older, otherwise "Minor".

# %%
age = int(input("Enter your age: "))
# Replace here:
status = ___
print(status)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# age = int(input("Enter your age: "))
# status = "Adult" if age >= 18 else "Minor"
# print(status)
# ```
# </details>

# %% [markdown]
# ### 3.2. Check Divisibility (Exercise 7)
# Use a conditional expression to set `result` to "Divisible by 3" if the number is divisible by 3, otherwise "Not divisible".

# %%
number = 9
# Replace here:
result = ___
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 9
# result = "Divisible by 3" if number % 3 == 0 else "Not divisible"
# print(result)
# ```
# </details>

# %% [markdown]
# ### 3.3. Setting a Boolean Flag (Exercise 8)
# Write a small program that:
# 1. Define `is_logged_in = False` and `username = "user123"`.
# 2. Use an `if` statement to set `is_logged_in` to `True` if `username` is not an empty string (`!= ""`).
# 3. Print the final value of `is_logged_in`.

# %%
is_logged_in = False
username =  "user123"
# Replace here:
if username ___:
    is_logged_in = ___

print(is_logged_in)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# is_logged_in = False
# username = "user123"
# if username != "":
#     is_logged_in = True
#
# print(is_logged_in)
# ```
# </details>

# %% [markdown]
# ## 4. Mini-Challenge (Exercises 9-10 of 10)

# %% [markdown]
# ### 4.1. Grade Evaluator (Exercise 9)
# Ask the user for a score (0–100). Print "Pass" if 70 or more, "Fail" otherwise.

# %%
# Write your code here
# 1. Ask the user for the score (int)
# 2. Use an if/else block to determine pass or fail (>=70)
# 3. Print the result

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# score = int(input("Enter score: "))
# if score >= 70:
#     print("Pass")
# else:
#     print("Fail")
# ```
# </details>

# %% [markdown]
# ### 4.2. Simple Login (Exercise 10)
# Ask the user for a password. Print "Access granted" if it matches "python123", otherwise "Access denied".
#
# *Note*: In real applications, passwords are never handled this way; secure authentication requires specialized libraries.

# %%
# Write your code here
# 1. Ask the user for the password (string)
# 2. Use an if/else block to check the password
# 3. Print the appropriate message

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# password = input("Enter password: ")
# if password == "python123":
#     print("Access granted")
# else:
#     print("Access denied")
# ```
# </details>

# %% [markdown]
# ---
# ## You're done!
# You practiced:
# - Relational operators
# - If statements
# - If-else statements
#
# Great work! Continue with the next notebook when ready.
