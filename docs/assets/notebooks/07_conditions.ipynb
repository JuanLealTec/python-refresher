# %% [markdown]
# ## Before You Begin
#
# Recommended steps:
# - Save your own copy of this notebook: File → Save a copy in Drive.
# - Run all cells from top to bottom.
# - Edit code only where the instructions indicate.
# - This notebook uses basic Python only; it does not connect to external files or services.
# - If something stops working, restart the notebook: Runtime → Restart session.

# %% [markdown]
# # Conditional Statements
#
# In this notebook, you will practice Python conditional statements, including `if`, `else`, and `elif`.
#
# You will complete **ten exercises** to reinforce these concepts.

# %% [markdown]
# ## 1. Warm-Up Exercise (1 of 10)
# ### 1.1 Compare two numbers
# Check if 5 is greater than 3 and print the result.

# %%
result = ___  # Replace with: 5 > 3
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# result = 5 > 3
# print(result)
# ```
# </details>

# %% [markdown]
# ## 2. Core Concepts (Exercises 2–5 of 10)
# Practice essential conditional operations.

# %% [markdown]
# ### 2.1 Simple if statement
# Print 'Yes' if a number is positive.

# %%
number = 7
if ___:  # Replace with: number > 0
    print('Yes')

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 7
# if number > 0:
#     print('Yes')
# ```
# </details>

# %% [markdown]
# ### 2.2 If-else statement
# Print 'Even' if a number is even, otherwise print 'Odd'.

# %%
number = 8
if number % 2 == 0:
    print('Even')
else:
    print('___')  # Replace with: 'Odd'

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 8
# if number % 2 == 0:
#     print('Even')
# else:
#     print('Odd')
# ```
# </details>

# %% [markdown]
# ### 2.3 Elif statement
# Check a score: print 'A' if >= 90, 'B' if >= 80, otherwise 'C'.

# %%
score = 85
if score >= 90:
    grade = 'A'
elif ___:  # Replace with: score >= 80
    grade = 'B'
else:
    grade = 'C'
print(grade)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# score = 85
# if score >= 90:
#     grade = 'A'
# elif score >= 80:
#     grade = 'B'
# else:
#     grade = 'C'
# print(grade)
# ```
# </details>

# %% [markdown]
# ### 2.4 Nested if statements
# Check if a number is positive and even, and print a message.

# %%
number = 4
if number > 0:
    if ___:  # Replace with: number % 2 == 0
        print('Positive and even')
    else:
        print('Positive but odd')

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 4
# if number > 0:
#     if number % 2 == 0:
#         print('Positive and even')
#     else:
#         print('Positive but odd')
# ```
# </details>

# %% [markdown]
# ## 3. Guided Practice (Exercises 6–8 of 10)
# Modify only the indicated lines only.

# %% [markdown]
# ### 3.1 Age check
# Ask the user for their age and print 'Adult' if 18 or older, otherwise 'Minor'.

# %%
age = int(input('Enter your age: '))
status = ___  # Replace with: 'Adult' if age >= 18 else 'Minor'
print(status)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# age = int(input('Enter your age: '))
# status = 'Adult' if age >= 18 else 'Minor'
# print(status)
# ```
# </details>

# %% [markdown]
# ### 3.2 Temperature advice
# Print advice based on temperature: cold (<15), warm (15 to 25 inclusive), hot (>25).

# %%
temp = 20
if temp < 15:
    advice = 'Cold'
elif ___:  # Replace with: temp <= 25
    advice = 'Warm'
else:
    advice = 'Hot'
print(advice)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# temp = 20
# if temp < 15:
#     advice = 'Cold'
# elif temp <= 25:
#     advice = 'Warm'
# else:
#     advice = 'Hot'
# print(advice)
# ```
# </details>

# %% [markdown]
# ### 3.3 Check divisibility
# Print 'Divisible by 3' if the number is divisible by 3, otherwise 'Not divisible'.

# %%
number = 9
result = ___  # Replace with: 'Divisible by 3' if number % 3 == 0 else 'Not divisible'
print(result)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# number = 9
# result = 'Divisible by 3' if number % 3 == 0 else 'Not divisible'
# print(result)
# ```
# </details>

# %% [markdown]
# ## 4. Mini-Challenge (Exercises 9–10 of 10)
# Apply conditional statements to small programs.

# %% [markdown]
# ### 4.1 Grade evaluator
# Ask the user for a score (0–100) and print 'Pass' if 70 or more, 'Fail' otherwise.

# %%
# Write your code here
score = int(input('Enter score: '))
# Determine pass or fail based on score (>=70)
# Print the result

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# score = int(input('Enter score: '))
# if score >= 70:
#     print('Pass')
# else:
#     print('Fail')
# ```
# </details>

# %% [markdown]
# ### 4.2 Simple login
# Ask the user for a password. Print 'Access granted' if it matches 'python123', otherwise 'Access denied'.

# %%
# Write your code here
password = input('Enter password: ')
# Check password and print appropriate message

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# password = input('Enter password: ')
# if password == 'python123':
#     print('Access granted')
# else:
#     print('Access denied')
# ```
# </details>

# %% [markdown]
# ---
# ## You're done!
# You practiced:
# - If statements
# - If-else and elif statements
# - Nested conditions
# - Conditional expressions and user input
#
# Great work! Continue with the next notebook when ready.
