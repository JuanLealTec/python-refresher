# %% [markdown]
# ## Before You Begin
#
# Recommended steps:
# - Save your own copy of this notebook: **File → Save a copy in Drive**.
# - Run all cells **from top to bottom**.
# - Edit code **only where the instructions indicate**.
# - This notebook uses basic Python only; it does not connect to external files or services.
# - If something stops working: **Runtime → Restart session**.

# %% [markdown]
# # Data Types
#
# In this notebook, you will work with Python’s four primitive data types:
# - **Integer** (`int`)
# - **Floating-point number** (`float`)
# - **Text** (`str`)
# - **Boolean** (`bool`)
#
# You will complete **ten beginner-friendly exercises** to recognize, create, and operate with these data types.

# %% [markdown]
# ## 1. Warm-Up Exercise (1 of 10)
# ### 1.1 Identify the type
# Use `type()` to print the data type of the variable `value`.

# %%
value = 15
print(type(___))   # <-- Replace with: value

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# value = 15
# print(type(value))
# ```
# </details>

# %% [markdown]
# ## 2. Core Concepts (Exercises 2–5 of 10)
# These exercises cover the essential data types used in Python.

# %% [markdown]
# ### 2.1 Create an integer
# Create a variable `age` and assign it any integer value.

# %%
age = ___   # <-- Replace with an integer, e.g. 17
print(age)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# age = 17
# print(age)
# ```
# </details>

# %% [markdown]
# ### 2.2 Create a float
# Create a variable `temperature` and assign it a floating-point value such as `20.5`.

# %%
temperature = ___   # <-- Replace with a float, e.g. 20.5
print(temperature)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# temperature = 20.5
# print(temperature)
# ```
# </details>

# %% [markdown]
# ### 2.3 Create a string
# Create a variable `city` containing the name of a city.

# %%
city = "___"   # <-- Replace with a city name, e.g. "Monterrey"
print(city)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# city = "Monterrey"
# print(city)
# ```
# </details>

# %% [markdown]
# ### 2.4 Create a boolean
# Create a variable `is_student` and set it to either `True` or `False`.

# %%
is_student = ___   # <-- Replace with: True or False
print(is_student)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# is_student = True
# print(is_student)
# ```
# </details>

# %% [markdown]
# ## 3. Guided Practice (Exercises 6–8 of 10)
# Work carefully and modify only the indicated elements.

# %% [markdown]
# ### 3.1 Convert string to integer
# Convert the string `"25"` into an integer and store it in `num`.

# %%
text_value = "25"
num = ___   # <-- Replace with: int(text_value)
print(num)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# text_value = "25"
# num = int(text_value)
# print(num)
# ```
# </details>

# %% [markdown]
# ### 3.2 Convert integer to string
# Convert the integer in `score` into a string and store it in `score_text`.

# %%
score = 90
score_text = ___   # <-- Replace with: str(score)
print(score_text)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# score = 90
# score_text = str(score)
# print(score_text)
# ```
# </details>

# %% [markdown]
# ### 3.3 Boolean check
# Create a variable `has_ticket` and set it to the result of checking whether `tickets` is greater than `0`.

# %%
tickets = 2
has_ticket = ___   # <-- Replace with: tickets > 0
print(has_ticket)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# tickets = 2
# has_ticket = tickets > 0
# print(has_ticket)
# ```
# </details>

# %% [markdown]
# ## 4. Mini-Challenge (Exercises 9–10 of 10)
# Apply the four primitive data types together.

# %% [markdown]
# ### 4.1 Mixed data types
# Create variables using all four data types (`int`, `float`, `str`, `bool`) and print them in one line.

# %%
a = ___       # <-- Replace with an integer, e.g. 10
b = ___       # <-- Replace with a float, e.g. 3.5
c = "___"     # <-- Replace with a string, e.g. "Hello"
d = ___       # <-- Replace with: True or False
print(a, b, c, d)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# a = 10
# b = 3.5
# c = "Hello"
# d = True
# print(a, b, c, d)
# ```
# </details>

# %% [markdown]
# ### 4.2 Mini-converter program
# Write a small program that:
# - Asks the user for their height in meters (string input)
# - Converts it to `float`
# - Multiplies it by `100`
# - Prints the height in centimeters

# %%
height_str = ___       # <-- Replace with: input("Height in meters: ")
height_m = ___         # <-- Replace with: float(height_str)
height_cm = ___        # <-- Replace with: height_m * 100
print(height_cm)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# height_str = input("Height in meters: ")
# height_m = float(height_str)
# height_cm = height_m * 100
# print(height_cm)
# ```
# </details>

# %% [markdown]
# ---
# ## 🎉 You're done!
# You practiced:
# - Creating and identifying data types
# - Converting between strings, integers, floats, and booleans
# - Writing beginner-level code using all four primitive types
#
# Great work! Continue with the next notebook when ready.
