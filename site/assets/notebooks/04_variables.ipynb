# %% [markdown]
# ## Before You Begin
#
# Recommended steps:
# - Save your own copy of this notebook: **File → Save a copy in Drive**
# - Run all cells **from top to bottom**
# - Edit code **only where the instructions indicate**
# - This notebook uses basic Python only; it does not connect to external files or services
# - If something stops working: **Runtime → Restart session**

# %% [markdown]
# # Variables & Constants
#
# This notebook introduces your first core programming tools:
# - How to create variables.
# - Naming rules and good practices.
# - Simple arithmetic with variables.
# - Python case sensitivity.
#
# You will complete ten beginner-friendly exercises, each with a short explanation and a solution you can expand when ready.

# %% [markdown]
# ## 1. Warm-Up Exercise (1 of 10)
# ### 1.1. Display a variable
# Create a variable named `user_name` and assign your name to it. Then print it.
#
# Modify only what is indicated.

# %%
# Replace the placeholder with your name (keep quotes)
user_name = "___"   # <-- Replace with your name, e.g. "Alex"
print(user_name)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# user_name = "Alex"
# print(user_name)
# ```
# </details>

# %% [markdown]
# ## 2. Core Concepts (Exercises 2–5 of 10)

# %% [markdown]
# ### 2.1. Basic assignment
# Fix the code by assigning the value 42 to the variable answer.
#
# Modify only the placeholder.

# %%
# Replace the placeholder with the correct integer value
answer = ___   # Replace with: 42
print(answer)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# answer = 42
# print(answer)
# ```
# </details>

# %% [markdown]
# ### 2.2. Updating a variable
# A store gives a 10% discount. Update the value of `price` so it reflects the new price.
#
# Modify only the placeholder.

# %%
price = 50
# Update price here (replace the placeholder)
price = ___    # Replace with: price * 0.9
print(price)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# price = 50
# price = price * 0.9
# print(price)
# ```
# </details>

# %% [markdown]
# ### 2.3. Swapping values
# Swap the values of `a` and `b` using a temporary variable.
#
# Replace each placeholder as instructed.

# %%
a = 3
b = 7
# Use a temporary variable to swap the values of a and b
temp = ___    # Replace with: a
a = ___       # Replace with: b
b = ___       # Replace with: temp
print(a, b)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# a = 3
# b = 7
# temp = a
# a = b
# b = temp
# print(a, b)
# ```
# </details>

# %% [markdown]
# ### 2.4. Simple arithmetic with variables
# Create a variable `x`, assign it the value `8`, and print the result of `x * 3`.
#
# Modify only the placeholder.

# %%
# Replace the placeholder with the integer 8
x = ___    # Replace with: 8
print(x * 3)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# x = 8
# print(x * 3)
# ```
# </details>

# %% [markdown]
# ## 3. Guided Practice (Exercises 6–8 of 10)

# %% [markdown]
# ### 3.1. Case sensitivity and naming conventions
# Use the correct variable names to print both values.
#
# Modify only the placeholders.

# %%
User_id = "A0103"     # Not recommended: variable name starts with uppercase
user_id = 103         # Different variable: lowercase user_id is not the same as User_id
# Print both variables here:
print(___, ___)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# User_id = "A0103"
# user_id = 103
# print(User_id, user_id)
# ```
# </details>

# %% [markdown]
# ### 3.2. Updating balance
# A user deposits 30 pesos into their wallet. Update `balance` accordingly.
#
# Replace only the placeholder.

# %%
balance = 120
# Update here:
balance = ___
print(balance)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# balance = 120
# balance = balance + 30
# print(balance)
# ```
# </details>

# %% [markdown]
# ### 3.3. Temperature conversion
# Convert `celsius` into Fahrenheit using the formula:
#
# `F = C * 1.8 + 32`
#
# Replace the placeholder to compute `fahrenheit`.

# %%
celsius = 20
# Convert here:
fahrenheit = ___
print(fahrenheit)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# celsius = 20
# fahrenheit = celsius * 1.8 + 32
# print(fahrenheit)
# ```
# </details>

# %% [markdown]
# ## 4. Mini-Challenge (Exercise 9 of 10)
# ### 4.1. Monthly savings
# Write a small program that:
# 1. Defines a variable `monthly_income`.
# 2. Defines another variable `savings_rate` (as a decimal).
# 3. Calculates the amount saved in one month.
# 4. Prints the amount saved.
#
# Replace only the placeholders below.

# %%
# Your code here - fill only the placeholders
monthly_income = ___   # Replace with a number, e.g. 8000
savings_rate = ___     # Replace with a decimal, e.g. 0.15
savings = ___          # Replace with: monthly_income * savings_rate
print(savings)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# monthly_income = 8000
# savings_rate = 0.15
# savings = monthly_income * savings_rate
# print(savings)
# ```
# </details>

# %% [markdown]
# ### 4.2. Combine inputs and variables
# Create a short program that:
# 1. Asks for the user's age (use `input()`).
# 2. Converts it to `int`.
# 3. Asks for the user's favorite number.
# 4. Converts it to `int`.
# 5. Prints the sum of both numbers.
#
# Replace only the placeholders below.

# %%
age_str = ___      # Replace with: input("Your age: ")
age = ___          # Replace with: int(age_str)
fav_str = ___      # Replace with: input("Favorite number: ")
fav = ___          # Replace with: int(fav_str)
total = ___        # Replace with: age + fav
print(total)

# %% [markdown]
# <details><summary><strong>Solution</strong></summary>
#
# ```python
# age_str = input("Your age: ")
# age = int(age_str)
# fav_str = input("Favorite number: ")
# fav = int(fav_str)
# total = age + fav
# print(total)
# ```
# </details>

# %% [markdown]
# ---
# ## You're done!
# You practiced:
# - Assigning and updating variables
# - Applying simple arithmetic
# - Understanding Python's case sensitivity
#
# Great job! Continue to the next notebook when ready.
